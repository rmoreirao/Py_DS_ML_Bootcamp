# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
sal = pd.read_csv('Salaries.csv')

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# ** Check the head of the DataFrame. **

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
# Id                  148654 non-null int64
# EmployeeName        148654 non-null object
# JobTitle            148654 non-null object
# BasePay             148045 non-null float64
# OvertimePay         148650 non-null float64
# OtherPay            148650 non-null float64
# Benefits            112491 non-null float64
# TotalPay            148654 non-null float64
# TotalPayBenefits    148654 non-null float64
# Year                148654 non-null int64
# Notes               0 non-null float64
# Agency              148654 non-null object
# Status              0 non-null float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 13.0+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
sal["BasePay"].mean()
# Out:
# 66325.4488404877

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
sal["OvertimePay"].mean()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
sal[sal['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
joseph = sal[sal['EmployeeName']=='JOSEPH DRISCOLL']
joseph[['BasePay','OvertimePay','OtherPay','Benefits']].sum(axis=1)
# expected:  270324.91
# Out:
# 24    270324.91
# dtype: float64

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
sal.iloc[sal['TotalPayBenefits'].idxmax()]

# Expected: NATHANIEL FORD
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                     167411
# OvertimePay                                                      0
# OtherPay                                                    400184
# Benefits                                                       NaN
# TotalPay                                                    567595
# TotalPayBenefits                                            567595
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal.iloc[sal['TotalPayBenefits'].idxmin()]
# Out:
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                      0
# OvertimePay                                  0
# OtherPay                               -618.13
# Benefits                                     0
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Notes                                      NaN
# Agency                           San Francisco
# Status                                     NaN
# Name: 148653, dtype: object

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
sal.groupby('Year').mean()['BasePay']
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# Expected:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
sal['JobTitle'].value_counts().head()

## Or sal.groupby('JobTitle').count().sort_values(by='Id',ascending=False).head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
sal[sal['Year'] == 2013]['JobTitle'].value_counts().where(lambda x:x == 1).dropna()
# Out:
# Mental Health Hearing Officer     1.0
# Principal Museum Preparator       1.0
# Special Assistant 21              1.0
# Farmer                            1.0
# Arborist Technician Supv II       1.0
# Rent Board Supervisor             1.0
# Assistant Industrial Hygienist    1.0
# IS Operator-Journey               1.0
# IS Trainer-Senior                 1.0
# Cement Finisher Supervisor 2      1.0
# Controller                        1.0
# Director, Juvenile Hall           1.0
# Field Svcs Asst Supv              1.0
# Sr Employee Asst Counselor        1.0
# Senior Psychiatric Orderly        1.0
# Assistant Power House Operator    1.0
# Senior Assessment Clerk           1.0
# Special Assistant 16              1.0
# Assistant Sheriff                 1.0
# Senior Transit Traffic Checker    1.0
# Statistician                      1.0
# Victim & Witness Technician       1.0
# Supervising Parts Storekeeper     1.0
# Payroll Supervisor                1.0
# Auto Body & Fender Wrk Sprv 1     1.0
# ...

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
sal[sal['JobTitle'].str.contains('Chief')]
# Out:
#             Id         EmployeeName                        JobTitle  \
# 36160    36161         Gregory Suhr                 Chief of Police
# 36162    36163   Joanne Hayes-White          Chief, Fire Department
# 36169    36170         Brendan Ward  Battlion Chief, Fire Suppressi
# 36170    36171           Samson Lai  Battlion Chief, Fire Suppressi
# 36171    36172     Rudy Castellanos  Battlion Chief, Fire Suppressi
# 36172    36173           Marty Ross  Battlion Chief, Fire Suppressi
# 36173    36174         Mark Kearney        Assistant Deputy Chief 2
# 36179    36180       Michael Morris        Assistant Deputy Chief 2
# 36181    36182         James Dudley                  Deputy Chief 3
# 36190    36191        Thomas Harvey        Assistant Deputy Chief 2
# 36196    36197          David Shinn                  Deputy Chief 3
# 36197    36198        Kevin Cashman                  Deputy Chief 3
# 36201    36202          Pete Fay Jr  Battlion Chief, Fire Suppressi
# ...

# %%
# Out:
# 477

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
sal['JobTitleLen'] = sal.apply(lambda row: len(row['JobTitle']), axis=1)
sal['JobTitleLen'].corr(sal['TotalPayBenefits'])

# Or the Code Below! Which is much faster!!
# Out:
# -0.036878445932606634

# %%
sal['JobTitleLen'] = sal['JobTitle'].apply(len)
sal[['JobTitleLen','TotalPayBenefits']].corr()
# Out:
#                   JobTitleLen  TotalPayBenefits
# JobTitleLen          1.000000         -0.036878
# TotalPayBenefits    -0.036878          1.000000

# %%
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %% [markdown]
# # Great Job!
